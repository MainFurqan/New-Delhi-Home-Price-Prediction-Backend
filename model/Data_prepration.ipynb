# %% [markdown]
# ## **Importing the Libraries**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Housing.csv")

df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
sns.histplot(data=df, x="price", kde=True)

plt.title("Distribution of Price")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.swarmplot(data=df, x="price")
# Out:
# <Axes: xlabel='price'>

# %%
df["price"].describe()
# Out:
# count    5.450000e+02
# mean     4.766729e+06
# std      1.870440e+06
# min      1.750000e+06
# 25%      3.430000e+06
# 50%      4.340000e+06
# 75%      5.740000e+06
# max      1.330000e+07
# Name: price, dtype: float64

# %%
df["price"].mode()
# Out:
# 0    3500000
# 1    4200000
# Name: price, dtype: int64

# %%
IQR = (5.740000e+06) - (3.430000e+06)
upper_fence = (1.5*IQR) + 5.740000e+06
print(upper_fence)
# Out:
# 9205000.0

# %%
sns.boxplot(data=df, x="price")
plt.title("Boxplot of 'Price' Attribute")
plt.show()

# %% [markdown]
# Negatively skewed but I think it is real data, in which have the few extreme values but I think it is real.
#
#
# =========================================================================================================

# %%
sns.histplot(data=df, x="area", kde=True)
plt.show()

# %%
sns.boxplot(data=df, x="area")
plt.show()

# %%
sns.swarmplot(data=df, x="area")
# Out:
# <Axes: xlabel='area'>

# %%
df["area"].describe()
# Out:
# count      545.000000
# mean      5150.541284
# std       2170.141023
# min       1650.000000
# 25%       3600.000000
# 50%       4600.000000
# 75%       6360.000000
# max      16200.000000
# Name: area, dtype: float64

# %%
df["area"].mode()
# Out:
# 0    6000
# Name: area, dtype: int64

# %%
df["area"].value_counts().head(10)
# Out:
# area
# 6000    24
# 3000    14
# 4500    13
# 4000    11
# 6600     9
# 5500     9
# 3600     8
# 3180     7
# 4040     7
# 3640     7
# Name: count, dtype: int64

# %% [markdown]
# their distribution is multimodel and non_normal and irregular, this attribute case " median < mean < mode "
#
#
# ___________________________________________________________________________________________________________________________

# %%
sns.countplot(data=df, x="bedrooms")
plt.show()

# %%
sns.countplot(data=df, x="bathrooms")
plt.show()

# %%
sns.countplot(data=df, x="stories")
plt.show()

# %%
sns.countplot(data=df, x="mainroad")
plt.show()

# %%
percent = df["mainroad"].value_counts(normalize=True)*100

percent.plot(kind="bar", color="skyblue")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Highly Imbalance Attribute, I think It is very importatn feature
#
# =======================================================================================

# %%
sns.countplot(data=df, x="guestroom")
plt.show()

# %%
percent = df["guestroom"].value_counts(normalize=True)*100
percent.plot(kind="bar")
plt.show()

# %% [markdown]
# this is also highly imbalance attribute
#
# --------------------------------------------------------------

# %%
sns.countplot(data=df, x="basement")
plt.show()

# %%
percent = df["basement"].value_counts(normalize=True)*100
percent.plot(kind="bar")
plt.show()

# %% [markdown]
# It is not such a high imbalance but not perfectly balance
#
#
# =================================================

# %%
sns.countplot(data=df, x="hotwaterheating")
plt.show()

# %%
percent = df["hotwaterheating"].value_counts(normalize=True)*100
percent.plot(kind="bar")
plt.show()

# %% [markdown]
# Highly imbalance
#
# ========================

# %%
sns.countplot(data=df, x="airconditioning")
plt.show()

# %%
percent = df["airconditioning"].value_counts(normalize=True)*100
percent.plot(kind="bar")
plt.show()

# %% [markdown]
# Imbalance

# %%
sns.countplot(data=df, x="parking")
plt.show()

# %%
sns.countplot(data=df, x="prefarea")
plt.show()

# %% [markdown]
# Hightly imbalance and important feature
#
#
# =========================================

# %%
sns.countplot(data=df, x="furnishingstatus")
plt.show()

# %% [markdown]
# approximately balance and important feature
#
# ===================================

# %% [markdown]
# Target(price) vs Area

# %%
sns.scatterplot(data=df,
                x="area", 
                y="price",
                alpha=0.8                # Transparency for overlapping points
            )
plt.title("Scatter Plot: Area vs Price")
plt.show()

# %% [markdown]
# price vs mainroad

# %%
sns.boxplot(data=df, y="price", x="mainroad")
plt.show()

# %%
sns.swarmplot(data=df, y="price", x="mainroad")
# Out:
# <Axes: xlabel='mainroad', ylabel='price'>
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(data=df, y="price", x="mainroad")
# Out:
# <Axes: xlabel='mainroad', ylabel='price'>

# %% [markdown]
# price vs prefarea

# %%
sns.boxplot(data=df, y="price", x="prefarea")
plt.show()

# %%
sns.swarmplot(data=df, y="price", x="prefarea")
plt.show()
# Out:
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(data=df, y="price", x="prefarea")
# Out:
# <Axes: xlabel='prefarea', ylabel='price'>

# %%
df.groupby("prefarea")["price"].describe()
# Out:
#           count          mean           std        min        25%        50%  \
# prefarea
# no        417.0  4.425299e+06  1.695811e+06  1750000.0  3255000.0  4095000.0
# yes       128.0  5.879046e+06  1.984005e+06  2233000.0  4548250.0  5582500.0
#
#                 75%         max
# prefarea
# no        5110000.0  12250000.0
# yes       6650000.0  13300000.0

# %%
df.groupby("prefarea")["price"].value_counts().head(20)
# Out:
# prefarea  price
# no        3500000    15
#           4200000    15
#           4900000    12
#           3150000     9
#           2940000     8
#           3360000     8
#           2660000     7
#           3010000     7
#           3290000     7
#           3640000     7
#           2450000     6
#           3920000     6
#           4270000     6
#           5600000     6
#           3710000     5
#           3780000     5
#           3850000     5
#           4340000     5
#           4480000     5
#           5250000     5
# Name: count, dtype: int64

# %%
sns.violinplot(data=df,
               y="prefarea",
               x="price")
# Out:
# <Axes: xlabel='price', ylabel='prefarea'>

# %% [markdown]
# Right tail of 'no' category is longer, I think it is true values.
#
# =========================================================

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# price vs bedrooms

# %%
sns.violinplot(data=df,
               y="price",
               x="bedrooms")
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.groupby("bedrooms")["price"].describe()
# Out:
#           count          mean           std        min        25%        50%  \
# bedrooms
# 1           2.0  2.712500e+06  6.187184e+05  2275000.0  2493750.0  2712500.0
# 2         136.0  3.632022e+06  1.004024e+06  1750000.0  2992500.0  3535000.0
# 3         300.0  4.954598e+06  1.747527e+06  1750000.0  3640000.0  4620000.0
# 4          95.0  5.729758e+06  2.307740e+06  2100000.0  4095000.0  5250000.0
# 5          10.0  5.819800e+06  2.502315e+06  1960000.0  3972500.0  5582500.0
# 6           2.0  4.791500e+06  1.826457e+06  3500000.0  4145750.0  4791500.0
#
#                 75%         max
# bedrooms
# 1         2931250.0   3150000.0
# 2         4217500.0   7070000.0
# 3         5967500.0  12250000.0
# 4         6912500.0  13300000.0
# 5         7700000.0  10150000.0
# 6         5437250.0   6083000.0

# %%
sns.swarmplot(data=df,
               y="price",
               x="bedrooms")
# Out:
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 19.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 30.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='bedrooms', ylabel='price'>
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 23.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 34.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ======================================================

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
sns.violinplot(data=df,
               y="price",
               x="bathrooms")
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
df.groupby("bathrooms")["price"].describe()
# Out:
#            count          mean           std         min         25%  \
# bathrooms
# 1          401.0  4.206913e+06  1.432609e+06   1750000.0   3234000.0
# 2          133.0  6.209206e+06  1.916503e+06   2380000.0   4893000.0
# 3           10.0  7.282100e+06  2.901083e+06   2660000.0   5110000.0
# 4            1.0  1.225000e+07           NaN  12250000.0  12250000.0
#
#                   50%         75%         max
# bathrooms
# 1           3990000.0   4900000.0  11410000.0
# 2           6090000.0   7350000.0  13300000.0
# 3           7315000.0  10032750.0  10850000.0
# 4          12250000.0  12250000.0  12250000.0

# %%
sns.swarmplot(data=df,
              x="bathrooms",
              y="price")
# Out:
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 29.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='bathrooms', ylabel='price'>
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# price vs furnishingstatus

# %%
sns.violinplot(data=df,
               x="furnishingstatus",
               y="price")
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='price'>

# %%
df.groupby("furnishingstatus")["price"].describe()
# Out:
#                   count          mean           std        min        25%  \
# furnishingstatus
# furnished         140.0  5.495696e+06  2.117857e+06  1750000.0  3876250.0
# semi-furnished    227.0  4.907524e+06  1.596688e+06  1767150.0  3850000.0
# unfurnished       178.0  4.013831e+06  1.720247e+06  1750000.0  2870000.0
#
#                         50%        75%         max
# furnishingstatus
# furnished         5075000.0  6650000.0  13300000.0
# semi-furnished    4585000.0  5582500.0  12250000.0
# unfurnished       3430000.0  4821250.0  10150000.0

# %%
sns.swarmplot(data=df,
               x="furnishingstatus",
               y="price")
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='price'>
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# price vs parking

# %%
sns.violinplot(data=df,
               x="parking",
               y="price")
# Out:
# <Axes: xlabel='parking', ylabel='price'>

# %%
df.groupby("parking")["price"].describe()
# Out:
#          count          mean           std        min        25%        50%  \
# parking
# 0        299.0  4.136017e+06  1.359445e+06  1750000.0  3150000.0  3850000.0
# 1        126.0  5.190389e+06  1.879971e+06  1855000.0  3552500.0  4690000.0
# 2        108.0  5.896328e+06  2.169085e+06  1820000.0  4324250.0  5302500.0
# 3         12.0  5.867167e+06  3.210310e+06  3010000.0  3998750.0  4375000.0
#
#                75%         max
# parking
# 0        4900000.0  10150000.0
# 1        6807500.0   9800000.0
# 2        6816250.0  13300000.0
# 3        6597500.0  12250000.0

# %%
sns.swarmplot(data=df,
               x="parking",
               y="price")
# Out:
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 16.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='parking', ylabel='price'>
# e:\Downloads\miniconda_setup\setup\envs\DP\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 24.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# price vs airconditioning

# %%
sns.violinplot(data=df,
               x="airconditioning",
               y="price")
# Out:
# <Axes: xlabel='airconditioning', ylabel='price'>

# %%
df.groupby("airconditioning")["price"].describe()
# Out:
#                  count          mean           std        min        25%  \
# airconditioning
# no               373.0  4.191940e+06  1.493712e+06  1750000.0  3150000.0
# yes              172.0  6.013221e+06  1.998149e+06  2233000.0  4602500.0
#
#                        50%        75%         max
# airconditioning
# no               3885000.0  4900000.0  12250000.0
# yes              5757500.0  7218750.0  13300000.0
